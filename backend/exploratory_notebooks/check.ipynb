# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\AliAsh\Sync\TimeSeriesProject\TimeSearies_toolkit-\backend\data\raw_data\task.csv') 
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383187 entries, 0 to 383186
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  383187 non-null  datetime64[ns]
#  1   value      383187 non-null  float64
#  2   engine_id  383187 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 8.8 MB

# %%
df.sort_values(by='timestamp', inplace=True)

# # Plotting the data
# # plt.figure(figsize=(10, 6))
# plt.plot(df['timestamp'], df['value'], color='b')
# plt.xlabel('Timestamp')
# plt.ylabel('Value')
# plt.title('Timestamp vs Value')
# plt.xticks(rotation=45)
# plt.tight_layout()

# # Show the plot
# plt.show()

# Group data by engine_id and plot each group
for engine_id, group in df.groupby('engine_id'):
    plt.plot(group['timestamp'], group['value'], label=f'Engine {engine_id}')

plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Timestamp vs Value')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
